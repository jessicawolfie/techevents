# %%
import pandas as pd
import uuid

# Curadoria de eventos REAIS e gigantes de tecnologia para 2026
real_events_2026 = [
    {
        "title": "Web Summit Rio 2026",
        "date": "2026-04-27",
        "time": "09:00",
        "location": "Rio de Janeiro, RJ",
        "is_online": False,
        "tags": ["inovação", "startups", "tecnologia", "networking", "negócios"],
        "image_url": "https://images.unsplash.com/photo-1540575467063-178a50c2df87?auto=format&fit=crop&w=600&q=80"
    },
    {
        "title": "Google I/O 2026",
        "date": "2026-05-12",
        "time": "14:00",
        "location": "Remoto",
        "is_online": True,
        "tags": ["android", "kotlin", "ai", "gemini", "firebase", "web"],
        "image_url": "https://images.unsplash.com/photo-1573164713988-8665fc963095?auto=format&fit=crop&w=600&q=80"
    },
    {
        "title": "Apple WWDC 2026",
        "date": "2026-06-08",
        "time": "14:00",
        "location": "Remoto",
        "is_online": True,
        "tags": ["ios", "swift", "machine learning", "mobile", "design"],
        "image_url": "https://images.unsplash.com/photo-1517245386807-bb43f82c33c4?auto=format&fit=crop&w=600&q=80"
    },
    {
        "title": "TDC (The Developer's Conference) SP",
        "date": "2026-07-21",
        "time": "08:30",
        "location": "São Paulo, SP",
        "is_online": False,
        "tags": ["java", "python", "agile", "arquitetura", "dados", "backend"],
        "image_url": "https://images.unsplash.com/photo-1505373877841-8d25f7d46678?auto=format&fit=crop&w=600&q=80"
    },
    {
        "title": "Python Brasil 2026",
        "date": "2026-10-15",
        "time": "09:00",
        "location": "Manaus, AM",
        "is_online": False,
        "tags": ["python", "data science", "comunidade", "django", "machine learning"],
        "image_url": "https://images.unsplash.com/photo-1526379095098-d400fd0bfce8?auto=format&fit=crop&w=600&q=80"
    },
    {
        "title": "AWS re:Invent 2026 Recap BR",
        "date": "2026-12-10",
        "time": "18:00",
        "location": "São Paulo, SP",
        "is_online": False,
        "tags": ["cloud", "aws", "devops", "infraestrutura", "segurança"],
        "image_url": "https://images.unsplash.com/photo-1451187580459-43490279c0fa?auto=format&fit=crop&w=600&q=80"
    },
    {
        "title": "Data Science e IA Summit",
        "date": "2026-08-05",
        "time": "10:00",
        "location": "Remoto",
        "is_online": True,
        "tags": ["data science", "machine learning", "pandas", "llm", "ai"],
        "image_url": "https://images.unsplash.com/photo-1551288049-bebda4e38f71?auto=format&fit=crop&w=600&q=80"
    },
    {
        "title": "Front-End Week",
        "date": "2026-09-20",
        "time": "19:00",
        "location": "Remoto",
        "is_online": True,
        "tags": ["react", "javascript", "css", "typescript", "ux"],
        "image_url": "https://images.unsplash.com/photo-1633356122544-f134324a6cee?auto=format&fit=crop&w=600&q=80"
    }
]

# Criando o DataFrame
df = pd.DataFrame(real_events_2026)

# Gerando os IDs únicos para o App Android
df['id'] = [str(uuid.uuid4()) for _ in range(len(df))]

# Exportando o JSON final limpo
caminho_arquivo = 'events_dataset.json'
df.to_json(caminho_arquivo, orient='records', force_ascii=False, indent=4)

display(df)
# Out:
#                                  title        date   time            location  \
# 0                  Web Summit Rio 2026  2026-04-27  09:00  Rio de Janeiro, RJ
# 1                      Google I/O 2026  2026-05-12  14:00              Remoto
# 2                      Apple WWDC 2026  2026-06-08  14:00              Remoto
# 3  TDC (The Developer's Conference) SP  2026-07-21  08:30       São Paulo, SP
# 4                   Python Brasil 2026  2026-10-15  09:00          Manaus, AM
# 5          AWS re:Invent 2026 Recap BR  2026-12-10  18:00       São Paulo, SP
# 6             Data Science e IA Summit  2026-08-05  10:00              Remoto
# 7                       Front-End Week  2026-09-20  19:00              Remoto
#
#    is_online                                               tags  \
# 0      False  [inovação, startups, tecnologia, networking, n...
# 1       True       [android, kotlin, ai, gemini, firebase, web]
# 2       True     [ios, swift, machine learning, mobile, design]
# ...
